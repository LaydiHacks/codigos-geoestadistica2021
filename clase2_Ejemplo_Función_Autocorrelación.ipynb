# %% [markdown]
# <a href="https://colab.research.google.com/github/laydihacks/codigos-geoestadistica2021/blob/main/clase2_Ejemplo_Funci%C3%B3n_Autocorrelaci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Función de Autocorrelación**

# %%
x <- c(-1,2,0,-2,1)
acf.x <- acf(x)
acf.x
# Out:
# Autocorrelations of series ‘x’, by lag
#
#    0    1    2    3    4
#  1.0 -0.4 -0.4  0.4 -0.1
# Plot with title “Series  x”
